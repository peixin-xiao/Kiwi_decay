# %%
# Calculate miu_a, miu_s through x*h=y, x = f(miu_a,miu_s);no deconvolution
import pandas as pd
from pandas import DataFrame,Series
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt
# import tensorflow as tf
# import tensorflow.keras as keras
import math
# from scipy.optimize import fsolve
# from scipy.optimize import root
from scipy.optimize import minimize
from scipy import signal
from scipy import linalg
# import scipy as scp
# import sympy as  syp
# from tensorflow.keras import backend as K
# from tensorflow.keras.layers import Layer
# from tensorflow.keras.models import Sequential
import gc

# %%
class process_hyperspec(object):
    
    def __init__(self, path, scat):
        self.path = path
        self.scat = scat
        
    def read_data(self):
        ## Read data from txt
        with open(self.path,'r',encoding='utf-8') as f:
            content = f.read()
        
        flag = 0
        for index in range(len(content)):##find the start point  of time and intensity data, pointer is the 'index'
            if (content[index] == '\n') and (flag != 1):
                flag = flag + 1
            elif (content[index] == '\n') and (flag == 1):
                break
            else:
                continue

        # print(content[index+7:len(content)])
        data_ns = pd.read_csv(StringIO(content[index+7:len(content)])) ## Read data of time and wavelengths
        img_nm_ns = np.array(data_ns)    ## Transform to numpy array                                
        self.data_frame = data_ns
        self.data_array = img_nm_ns
        
    def cal_846nm(self):
        time_total, wavelength_total = self.data_array.shape ## Generate an array contains intensity versus time data on 846nm
        data_846nm = np.zeros((time_total,), dtype = float )
        for i in range(wavelength_total):
            data_846nm = self.data_array[:,i] + data_846nm

        return data_846nm/wavelength_total
    
    def return_dataframe(self):
        
        return self.data_frame
    
    def return_array(self):
        return self.data_array

# %%
def name_g(i):

    return str(2*i+1)
    
    

dict1 = {i:'s_'+ name_g(i) +'days.txt' for i in range(1, 7)}
dict1[0] = 's_1day.txt'
# dict1[-1] = 'Ref_846nm_5ns.txt'
dict1[-1] = 'Ref_846nm_5ns_15.txt'

N = 8
scat = [None]*N
n_time_labels = 480
data_480multi9 = np.zeros((N, n_time_labels), dtype = float)
for i in range(0, N):
    scat[i] = process_hyperspec(dict1[i-1], i)
    scat[i].read_data()
    data_480multi9[i,:] = scat[i].cal_846nm()

time_index = scat[0].return_dataframe().index

plt.figure(figsize = (10,10))
for i in range(0, N):
    plt.subplot(3,3,i+1)
    plt.plot(data_480multi9[i,:])
    
plt.show()

# print(time_index)

del scat, dict1, name_g, process_hyperspec
gc.collect()
# Out:
# 20739

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts) / box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth



def split_signal(y):
    THRESHOLD_V = 0.02
    for i in range(len(y)):
        if y[i] > THRESHOLD_V and y[i-1] <= THRESHOLD_V:
            index1  = i
        elif y[i] < THRESHOLD_V and y[i-1] >= THRESHOLD_V:
            index2 = i
    y2 = np.zeros((index2 - index1 + 1,))
    y2 = y[index1:index2]
        
    return y2, index1

# %%
#Generate h,y(x*h = y)
#===================================================================================================
# data_intensity_extended = np.zeros((N, 959), dtype = float)
# data_intensity_extended[:, 0:479]  = data_480multi9[:,0:479]
# MAX = np.max(data_480multi9)
# # h = smooth(data_480multi9[0,:]/max(data_480multi9[0,:]), 10) #x*h = y ; x.shape = (480,) h.shape = (480,) y.shape = (959,)
# h = smooth(data_480multi9[0,:]/MAX, 10)

# y =np.zeros((N,959))
# for i in range(0,N):
#     y[i,:] = smooth(data_intensity_extended[i,:]/max(data_intensity_extended[i,:]), 10)
    
#======================================================================================================

# %%
data_intensity_extended = np.zeros((N, 959), dtype = float)
data_intensity_extended[:, 0:479]  = data_480multi9[:,0:479]

# h = smooth(data_480multi9[0,:], 1)
h = data_480multi9[0,:]

y =np.zeros((N,959))
for i in range(0,N):
    # y[i,:] = smooth(data_intensity_extended[i,:], 1)
    y[i,:] = data_intensity_extended[i,:]

# %%
class calculate_miu_s(object):
    
    def __init__(self, h, y, time_index, k):
        self.h = h
        self.y = y
        self.time = time_index
        self.k = k
        return None
    
    def transmittance(self, d, t, c, g, miu_a, miu_s):
        miu_s_prime = (1-g)*miu_s
        Z0 = 1/(miu_s_prime)
        D = 1/(3*(miu_a + miu_s_prime))
        h1 = math.pow(4*math.pi*D*c, -0.5)
        h2 = math.pow(t, -1.5)*math.exp(-miu_a*c*t)
        h3 = (d-Z0)*math.exp(-(math.pow(d-Z0, 2))/(4*D*c*t))
        h4 = (d+Z0)*math.exp(-(math.pow(d+Z0, 2))/(4*D*c*t))
        h5 = (3*d-Z0)*math.exp(-(math.pow(3*d-Z0, 2))/(4*D*c*t))
        h6 = (3*d+Z0)*math.exp(-(math.pow(3*d+Z0, 2))/(4*D*c*t))
    #     return d,Z0,D,c,t
        return h1*h2*(h3-h4+h5-h6)
    
    
    def error_cal(self, x):
        miu_s = x[0]
        miu_a = x[1]
        k = self.k
        # k     = x[2]  
        # k = 0.1
        # miu_a = 0.01e2
        g = 0.7
        d = 0.01
        # t = 300e-12
        c = 3e8/1.3314
        T = int(480)
#         time = np.array(range(1,T, 1))
#         time = time*1e-8*0.010345058455114822
        time = self.time*1e-9
        miu_s = miu_s*1e4
        intensity1 = np.zeros((T, ), dtype = float)
        for i in range(time.shape[0] - 1):

            intensity1[i] = calculate_miu_s.transmittance(self, d, time[i], c, g, miu_a, miu_s)
        
        y2 = np.convolve(intensity1, self.h)
        self.intensity = intensity1
        self.y_convolved = y2
        # y2 = y2/max(y2)
        y2 = y2*k*1e-9
        return np.sum(abs(y2 - self.y))
#         return time

    def get_convolved_signal(self):
        return self.y_convolved
        
    def get_x(self):
        return self.intensity

# %%
rr = calculate_miu_s(h, y[1,:], time_index)
minimize(rr.error_cal, x0 = [3, 6, 4], method  = 'Nelder-Mead', options={"xtol" : 1e-10, "disp":True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.653765
#          Iterations: 330
#          Function evaluations: 592
#  final_simplex: (array([[2.87436248, 4.71810427, 0.06306293],
#        [2.87436248, 4.71810427, 0.06306293],
#        [2.87436248, 4.71810427, 0.06306293],
#        [2.87436248, 4.71810427, 0.06306293]]), array([0.65376457, 0.65376457, 0.65376457, 0.65376457]))
#            fun: 0.65376457484052
#        message: 'Optimization terminated successfully.'
#           nfev: 592
#            nit: 330
#         status: 0
#        success: True
#              x: array([2.87436248, 4.71810427, 0.06306293])

# %%
def get_error(x):    
    k = x[0]
    m = [None]*(N-1)
    sum_fun = 0
    for i in range(1,N):
        m[i-1] = calculate_miu_s(h, y[i], time_index, k)
        sum_fun = sum_fun + abs(minimize(m[i-1].error_cal, x0 = [3,6], method  = 'Nelder-Mead', options={"xtol" : 1e-20, "disp":True}).fun)
    return sum_fun

# %%
minimize(get_error, x0 = [0.1], method  = 'Nelder-Mead')
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.206838
#          Iterations: 129
#          Function evaluations: 286
# Optimization terminated successfully.
#          Current function value: 2.571085
#          Iterations: 183
#          Function evaluations: 372
# Optimization terminated successfully.
#          Current function value: 4.810809
#          Iterations: 154
#          Function evaluations: 306
# Optimization terminated successfully.
#          Current function value: 3.753011
#          Iterations: 155
#          Function evaluations: 314
# Optimization terminated successfully.
#          Current function value: 1.464539
#          Iterations: 143
#          Function evaluations: 285
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.197906
#          Iterations: 147
#          Function evaluations: 297
# Optimization terminated successfully.
#          Current function value: 2.570354
#          Iterations: 159
#          Function evaluations: 317
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.466987
#          Iterations: 133
#          Function evaluations: 264
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.190612
#          Iterations: 135
#          Function evaluations: 275
# Optimization terminated successfully.
#          Current function value: 2.569707
#          Iterations: 147
#          Function evaluations: 295
# Optimization terminated successfully.
#          Current function value: 4.659779
#          Iterations: 145
#          Function evaluations: 302
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.865931
#          Iterations: 143
#          Function evaluations: 283
# Optimization terminated successfully.
#          Current function value: 1.972890
#          Iterations: 158
#          Function evaluations: 308
# Optimization terminated successfully.
#          Current function value: 2.185051
#          Iterations: 125
#          Function evaluations: 255
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 4.591283
#          Iterations: 137
#          Function evaluations: 290
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.474475
#          Iterations: 121
#          Function evaluations: 252
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.175815
#          Iterations: 168
#          Function evaluations: 340
# Optimization terminated successfully.
#          Current function value: 2.570419
#          Iterations: 141
#          Function evaluations: 278
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.638329
#          Iterations: 169
#          Function evaluations: 343
# Optimization terminated successfully.
#          Current function value: 1.479193
#          Iterations: 137
#          Function evaluations: 274
# Optimization terminated successfully.
#          Current function value: 1.878719
#          Iterations: 119
#          Function evaluations: 237
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.158596
#          Iterations: 145
#          Function evaluations: 283
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 4.168899
#          Iterations: 149
#          Function evaluations: 299
# Optimization terminated successfully.
#          Current function value: 3.556545
#          Iterations: 155
#          Function evaluations: 310
# Optimization terminated successfully.
#          Current function value: 1.497339
#          Iterations: 140
#          Function evaluations: 283
# Optimization terminated successfully.
#          Current function value: 1.901627
#          Iterations: 165
#          Function evaluations: 338
# Optimization terminated successfully.
#          Current function value: 2.026943
#          Iterations: 148
#          Function evaluations: 293
# Optimization terminated successfully.
#          Current function value: 2.153764
#          Iterations: 125
#          Function evaluations: 247
# Optimization terminated successfully.
#          Current function value: 2.614040
#          Iterations: 130
#          Function evaluations: 261
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.525442
#          Iterations: 154
#          Function evaluations: 295
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.923005
#          Iterations: 131
#          Function evaluations: 257
# Optimization terminated successfully.
#          Current function value: 2.060028
#          Iterations: 135
#          Function evaluations: 271
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.740995
#          Iterations: 143
#          Function evaluations: 284
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.525258
#          Iterations: 159
#          Function evaluations: 311
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.090822
#          Iterations: 140
#          Function evaluations: 283
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.678723
#          Iterations: 138
#          Function evaluations: 273
# Optimization terminated successfully.
#          Current function value: 3.541546
#          Iterations: 133
#          Function evaluations: 262
# Optimization terminated successfully.
#          Current function value: 3.485176
#          Iterations: 143
#          Function evaluations: 281
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.989012
#          Iterations: 167
#          Function evaluations: 327
# Optimization terminated successfully.
#          Current function value: 2.147927
#          Iterations: 194
#          Function evaluations: 390
# Optimization terminated successfully.
#          Current function value: 2.195743
#          Iterations: 135
#          Function evaluations: 266
# Optimization terminated successfully.
#          Current function value: 2.735002
#          Iterations: 123
#          Function evaluations: 250
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.790330
#          Iterations: 183
#          Function evaluations: 361
# Optimization terminated successfully.
#          Current function value: 3.058995
#          Iterations: 158
#          Function evaluations: 316
# Optimization terminated successfully.
#          Current function value: 3.539014
#          Iterations: 147
#          Function evaluations: 280
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.790330
#          Iterations: 183
#          Function evaluations: 361
# Optimization terminated successfully.
#          Current function value: 3.058995
#          Iterations: 158
#          Function evaluations: 316
# Optimization terminated successfully.
#          Current function value: 3.539014
#          Iterations: 147
#          Function evaluations: 280
# Optimization terminated successfully.
#          Current function value: 1.558851
#          Iterations: 134
#          Function evaluations: 263
# Optimization terminated successfully.
#          Current function value: 2.007267
#          Iterations: 146
#          Function evaluations: 287
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.763954
#          Iterations: 148
#          Function evaluations: 294
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.517121
#          Iterations: 164
#          Function evaluations: 327
# Optimization terminated successfully.
#          Current function value: 1.537793
#          Iterations: 167
#          Function evaluations: 339
# Optimization terminated successfully.
#          Current function value: 1.968636
#          Iterations: 188
#          Function evaluations: 371
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.706046
#          Iterations: 133
#          Function evaluations: 272
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.484476
#          Iterations: 130
#          Function evaluations: 259
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.134449
#          Iterations: 163
#          Function evaluations: 317
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.320595
#          Iterations: 134
#          Function evaluations: 282
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.749408
#          Iterations: 143
#          Function evaluations: 283
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.546092
#          Iterations: 159
#          Function evaluations: 314
# Optimization terminated successfully.
#          Current function value: 1.984156
#          Iterations: 157
#          Function evaluations: 312
# Optimization terminated successfully.
#          Current function value: 2.141258
#          Iterations: 141
#          Function evaluations: 279
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.993706
#          Iterations: 151
#          Function evaluations: 302
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.742108
#          Iterations: 131
#          Function evaluations: 258
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.500707
#          Iterations: 127
#          Function evaluations: 250
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.738521
#          Iterations: 126
#          Function evaluations: 252
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.993706
#          Iterations: 151
#          Function evaluations: 302
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.742108
#          Iterations: 131
#          Function evaluations: 258
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.500707
#          Iterations: 127
#          Function evaluations: 250
# Optimization terminated successfully.
#          Current function value: 1.549314
#          Iterations: 158
#          Function evaluations: 310
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.196838
#          Iterations: 146
#          Function evaluations: 294
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.550591
#          Iterations: 156
#          Function evaluations: 311
# Optimization terminated successfully.
#          Current function value: 1.992546
#          Iterations: 180
#          Function evaluations: 359
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.199006
#          Iterations: 159
#          Function evaluations: 313
# Optimization terminated successfully.
#          Current function value: 2.740323
#          Iterations: 134
#          Function evaluations: 269
# Optimization terminated successfully.
#          Current function value: 3.238381
#          Iterations: 126
#          Function evaluations: 282
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.549631
#          Iterations: 141
#          Function evaluations: 276
# Optimization terminated successfully.
#          Current function value: 1.990789
#          Iterations: 150
#          Function evaluations: 298
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.249188
#          Iterations: 124
#          Function evaluations: 277
# Optimization terminated successfully.
#          Current function value: 3.498088
#          Iterations: 134
#          Function evaluations: 261
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.196838
#          Iterations: 149
#          Function evaluations: 297
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.252817
#          Iterations: 135
#          Function evaluations: 288
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.991083
#          Iterations: 151
#          Function evaluations: 299
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.197654
#          Iterations: 156
#          Function evaluations: 307
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.498335
#          Iterations: 131
#          Function evaluations: 257
# Optimization terminated successfully.
#          Current function value: 1.549473
#          Iterations: 137
#          Function evaluations: 275
# Optimization terminated successfully.
#          Current function value: 1.990494
#          Iterations: 150
#          Function evaluations: 299
# Optimization terminated successfully.
#          Current function value: 2.149910
#          Iterations: 157
#          Function evaluations: 309
# Optimization terminated successfully.
#          Current function value: 2.197111
#          Iterations: 154
#          Function evaluations: 308
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.251001
#          Iterations: 125
#          Function evaluations: 277
# Optimization terminated successfully.
#          Current function value: 3.497841
#          Iterations: 132
#          Function evaluations: 263
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.150500
#          Iterations: 165
#          Function evaluations: 332
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.248283
#          Iterations: 120
#          Function evaluations: 270
# Optimization terminated successfully.
#          Current function value: 3.498212
#          Iterations: 127
#          Function evaluations: 253
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.990642
#          Iterations: 168
#          Function evaluations: 326
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.250094
#          Iterations: 123
#          Function evaluations: 268
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 1.549591
#          Iterations: 142
#          Function evaluations: 281
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.737503
#          Iterations: 166
#          Function evaluations: 336
# Optimization terminated successfully.
#          Current function value: 3.249641
#          Iterations: 136
#          Function evaluations: 286
# Optimization terminated successfully.
#          Current function value: 3.498027
#          Iterations: 135
#          Function evaluations: 270
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.197247
#          Iterations: 156
#          Function evaluations: 315
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 3.497965
#          Iterations: 129
#          Function evaluations: 247
# Optimization terminated successfully.
#          Current function value: 1.549611
#          Iterations: 144
#          Function evaluations: 283
# Optimization terminated successfully.
#          Current function value: 1.990752
#          Iterations: 152
#          Function evaluations: 299
# Optimization terminated successfully.
#          Current function value: 2.150254
#          Iterations: 168
#          Function evaluations: 336
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
#  final_simplex: (array([[0.33867188],
#        [0.33859375]]), array([17.37299673, 17.37299744]))
#            fun: 17.37299672782606
#        message: 'Optimization terminated successfully.'
#           nfev: 32
#            nit: 16
#         status: 0
#        success: True
#              x: array([0.33867188])

# %%
miu_s_get = np.zeros((N-1,2))
m = [None]*(N-1)
fun_value = np.zeros((7,))
k = 0.33867188
for i in range(1,N):
    m[i-1] = calculate_miu_s(h, y[i], time_index, k)
    minu = minimize(m[i-1].error_cal, x0 = [3,6], method  = 'Nelder-Mead', options={"xtol" : 1e-20, "disp":True})
    miu_s_get[i-1,:], fun_value[i-1] = minu.x, minu.fun
# Out:
# Optimization terminated successfully.
#          Current function value: 1.461560
#          Iterations: 140
#          Function evaluations: 287
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Warning: Maximum number of function evaluations has been exceeded.
# Optimization terminated successfully.
#          Current function value: 2.639565
#          Iterations: 136
#          Function evaluations: 259

# %%
print(np.sum(abs(fun_value)))
print(fun_value)
plt.figure(figsize = (10,10))
for i in range (0, 7):
    yk = m[i].get_convolved_signal()
    plt.subplot(3,3,i+1)
    plt.plot(y[i+1])
    plt.plot(yk*k*1e-9)
plt.show()
# Out:
# 15.173905769621786
# [1.46155964 1.85216264 1.87301148 1.8677464  2.30934164 3.17051912
#  2.63956485]

# %%
# miu_s_get = np.array([[0.24,0.64],[0.56,0.91],[0.85,0.81],[1.24,0.79],[1.27,0.31],[1.51,0.30],[1.76,0.29],[2.44,0.51]])

# %%
miu_s_get
# Out:
# array([[3.9930833 , 9.35244295],
#        [3.74306756, 9.1056888 ],
#        [3.41804852, 9.44442661],
#        [3.35215541, 8.41431385],
#        [3.14997924, 8.49330909],
#        [3.37508089, 6.13732019],
#        [2.74584994, 8.05128486]])

# %%
plt.figure(figsize = (10,10))
plt.subplot(2,1,1)
plt.title("miu_s'") # 图形标题
# plt.xlabel("") # x轴名称
plt.ylabel("/m") # y 轴名称
plt.plot(miu_s_get[:,0]*1e4*0.3)
plt.subplot(2,1,2)
plt.title("miu_a") # 图形标题
# plt.xlabel("") # x轴名称
plt.ylabel("/m") # y 轴名称
plt.plot(miu_s_get[:,1])
plt.show()
